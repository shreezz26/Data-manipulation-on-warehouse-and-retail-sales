# %% [markdown]
# Data from CSV into Data Frame

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/Warehouse_and_Retail_Sales.csv")

# %%
df
# Out:
#         YEAR  MONTH                           SUPPLIER ITEM CODE  \
# 0       2020      1  REPUBLIC NATIONAL DISTRIBUTING CO    100009
# 1       2020      1                          PWSWN INC    100024
# 2       2020      1            RELIABLE CHURCHILL LLLP      1001
# 3       2020      1          LANTERNA DISTRIBUTORS INC    100145
# 4       2020      1               DIONYSOS IMPORTS INC    100293
# ...      ...    ...                                ...       ...
# 307640  2020      9                           DOPS INC     97896
# 307641  2020      9                 ANHEUSER BUSCH INC     97918
# 307642  2020      9                       HEINEKEN USA     97942
# 307643  2020      9            RELIABLE CHURCHILL LLLP     97950
# 307644  2020      9            RELIABLE CHURCHILL LLLP     97969
#
#                                    ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 0                               BOOTLEG RED - 750ML      WINE          0.00
# ...

# %%
df.head()
# Out:
#    YEAR  MONTH                           SUPPLIER ITEM CODE  \
# 0  2020      1  REPUBLIC NATIONAL DISTRIBUTING CO    100009
# 1  2020      1                          PWSWN INC    100024
# 2  2020      1            RELIABLE CHURCHILL LLLP      1001
# 3  2020      1          LANTERNA DISTRIBUTORS INC    100145
# 4  2020      1               DIONYSOS IMPORTS INC    100293
#
#                       ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 0                  BOOTLEG RED - 750ML      WINE          0.00
# 1            MOMENT DE PLAISIR - 750ML      WINE          0.00
# 2  S SMITH ORGANIC PEAR CIDER - 18.7OZ      BEER          0.00
# 3        SCHLINK HAUS KABINETT - 750ML      WINE          0.00
# 4       SANTORINI GAVALA WHITE - 750ML      WINE          0.82
#
#    RETAIL TRANSFERS  WAREHOUSE SALES
# 0               0.0              2.0
# 1               1.0              4.0
# 2               0.0              1.0
# 3               0.0              1.0
# ...

# %%
df.tail()
# Out:
#         YEAR  MONTH                 SUPPLIER ITEM CODE  \
# 307640  2020      9                 DOPS INC     97896
# 307641  2020      9       ANHEUSER BUSCH INC     97918
# 307642  2020      9             HEINEKEN USA     97942
# 307643  2020      9  RELIABLE CHURCHILL LLLP     97950
# 307644  2020      9  RELIABLE CHURCHILL LLLP     97969
#
#                                    ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 307640  ST PETERS ORGANIC ENG ALE NR 12/CS - 16.9OZ      BEER          0.00
# 307641               STELLA ARTOIS 2/12 NR - 11.2OZ      BEER        372.45
# 307642                       TECATE 4/6 LNNR - 12OZ      BEER          7.79
# 307643     S SMITH WINTER WELCOME NR 12/CS - 18.7OZ      BEER          0.00
# 307644          S SMITH WINTER WELCOME 4/6NR - 12OZ      BEER          0.00
#
#         RETAIL TRANSFERS  WAREHOUSE SALES
# 307640               0.0             1.00
# 307641             315.0          3586.88
# 307642               0.0             4.00
# ...

# %%
df['ITEM TYPE']
# Out:
# 0         WINE
# 1         WINE
# 2         BEER
# 3         WINE
# 4         WINE
#           ...
# 307640    BEER
# 307641    BEER
# 307642    BEER
# 307643    BEER
# 307644    BEER
# Name: ITEM TYPE, Length: 307645, dtype: object

# %%
df['ITEM TYPE'] == 'wine'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 307640    False
# 307641    False
# 307642    False
# 307643    False
# 307644    False
# Name: ITEM TYPE, Length: 307645, dtype: bool

# %%
df[   df['ITEM TYPE'] == 'beer']
# Out:
# Empty DataFrame
# Columns: [YEAR, MONTH, SUPPLIER, ITEM CODE, ITEM DESCRIPTION, ITEM TYPE, RETAIL SALES, RETAIL TRANSFERS, WAREHOUSE SALES]
# Index: []

# %%
df[ (df['ITEM TYPE'] == 'wine') & (df['SUPPLIER'] == 'DOPS INC')]
# Out:
# Empty DataFrame
# Columns: [YEAR, MONTH, SUPPLIER, ITEM CODE, ITEM DESCRIPTION, ITEM TYPE, RETAIL SALES, RETAIL TRANSFERS, WAREHOUSE SALES]
# Index: []

# %%
df[ (df['ITEM TYPE'] == 'wine') & (df['SUPPLIER'] == 'DOPS INC')].shape
# Out:
# (0, 9)

# %%
df[ (df['ITEM TYPE'] == 'wine') & (df['SUPPLIER'] == 'DOPS INC')]['MONTH'].count()
# Out:
# np.int64(0)

# %%
df['ITEM CODE'] * 2
# Out:
# 0         100009100009
# 1         100024100024
# 2             10011001
# 3         100145100145
# 4         100293100293
#               ...
# 307640      9789697896
# 307641      9791897918
# 307642      9794297942
# 307643      9795097950
# 307644      9796997969
# Name: ITEM CODE, Length: 307645, dtype: object

# %%
df['NEW_CODE'] = df['ITEM CODE'] * 2

# %%
df.head()
# Out:
#    YEAR  MONTH                           SUPPLIER ITEM CODE  \
# 0  2020      1  REPUBLIC NATIONAL DISTRIBUTING CO    100009
# 1  2020      1                          PWSWN INC    100024
# 2  2020      1            RELIABLE CHURCHILL LLLP      1001
# 3  2020      1          LANTERNA DISTRIBUTORS INC    100145
# 4  2020      1               DIONYSOS IMPORTS INC    100293
#
#                       ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 0                  BOOTLEG RED - 750ML      WINE          0.00
# 1            MOMENT DE PLAISIR - 750ML      WINE          0.00
# 2  S SMITH ORGANIC PEAR CIDER - 18.7OZ      BEER          0.00
# 3        SCHLINK HAUS KABINETT - 750ML      WINE          0.00
# 4       SANTORINI GAVALA WHITE - 750ML      WINE          0.82
#
#    RETAIL TRANSFERS  WAREHOUSE SALES      NEW_CODE
# 0               0.0              2.0  100009100009
# 1               1.0              4.0  100024100024
# 2               0.0              1.0      10011001
# ...

# %%
df['ITEM TYPE'].isna().sum()
# Out:
# np.int64(1)

# %%
df['ITEM TYPE'].value_counts()
# Out:
# ITEM TYPE
# WINE            187640
# LIQUOR           64910
# BEER             42413
# KEGS             10146
# NON-ALCOHOL       1908
# STR_SUPPLIES       405
# REF                127
# DUNNAGE             95
# Name: count, dtype: int64

# %%
def it(x):
  if x == 'wine':
    return 'Beer'
  else:
    return x

# %%
df['ITEM TYPE'].apply(it)
# Out:
# 0         WINE
# 1         WINE
# 2         BEER
# 3         WINE
# 4         WINE
#           ...
# 307640    BEER
# 307641    BEER
# 307642    BEER
# 307643    BEER
# 307644    BEER
# Name: ITEM TYPE, Length: 307645, dtype: object

# %%
df['it-b'] = df['ITEM TYPE'].apply(it)

# %%
df.head()
# Out:
#    YEAR  MONTH                           SUPPLIER ITEM CODE  \
# 0  2020      1  REPUBLIC NATIONAL DISTRIBUTING CO    100009
# 1  2020      1                          PWSWN INC    100024
# 2  2020      1            RELIABLE CHURCHILL LLLP      1001
# 3  2020      1          LANTERNA DISTRIBUTORS INC    100145
# 4  2020      1               DIONYSOS IMPORTS INC    100293
#
#                       ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 0                  BOOTLEG RED - 750ML      WINE          0.00
# 1            MOMENT DE PLAISIR - 750ML      WINE          0.00
# 2  S SMITH ORGANIC PEAR CIDER - 18.7OZ      BEER          0.00
# 3        SCHLINK HAUS KABINETT - 750ML      WINE          0.00
# 4       SANTORINI GAVALA WHITE - 750ML      WINE          0.82
#
#    RETAIL TRANSFERS  WAREHOUSE SALES      NEW_CODE  it-b
# 0               0.0              2.0  100009100009  WINE
# 1               1.0              4.0  100024100024  WINE
# ...

# %%
df['ITEM TYPE'].apply(lambda x: 'Beer' if x == 'wine' else x)
# Out:
# 0         WINE
# 1         WINE
# 2         BEER
# 3         WINE
# 4         WINE
#           ...
# 307640    BEER
# 307641    BEER
# 307642    BEER
# 307643    BEER
# 307644    BEER
# Name: ITEM TYPE, Length: 307645, dtype: object

# %%
df.drop(index = 12)
# Out:
#         YEAR  MONTH                           SUPPLIER ITEM CODE  \
# 0       2020      1  REPUBLIC NATIONAL DISTRIBUTING CO    100009
# 1       2020      1                          PWSWN INC    100024
# 2       2020      1            RELIABLE CHURCHILL LLLP      1001
# 3       2020      1          LANTERNA DISTRIBUTORS INC    100145
# 4       2020      1               DIONYSOS IMPORTS INC    100293
# ...      ...    ...                                ...       ...
# 307640  2020      9                           DOPS INC     97896
# 307641  2020      9                 ANHEUSER BUSCH INC     97918
# 307642  2020      9                       HEINEKEN USA     97942
# 307643  2020      9            RELIABLE CHURCHILL LLLP     97950
# 307644  2020      9            RELIABLE CHURCHILL LLLP     97969
#
#                                    ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 0                               BOOTLEG RED - 750ML      WINE          0.00
# ...

# %%
df.drop(index = 0)
# Out:
#         YEAR  MONTH                   SUPPLIER ITEM CODE  \
# 1       2020      1                  PWSWN INC    100024
# 2       2020      1    RELIABLE CHURCHILL LLLP      1001
# 3       2020      1  LANTERNA DISTRIBUTORS INC    100145
# 4       2020      1       DIONYSOS IMPORTS INC    100293
# 5       2020      1    KYSELA PERE ET FILS LTD    100641
# ...      ...    ...                        ...       ...
# 307640  2020      9                   DOPS INC     97896
# 307641  2020      9         ANHEUSER BUSCH INC     97918
# 307642  2020      9               HEINEKEN USA     97942
# 307643  2020      9    RELIABLE CHURCHILL LLLP     97950
# 307644  2020      9    RELIABLE CHURCHILL LLLP     97969
#
#                                    ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 1                         MOMENT DE PLAISIR - 750ML      WINE          0.00
# 2               S SMITH ORGANIC PEAR CIDER - 18.7OZ      BEER          0.00
# ...

# %%
df.drop(index = 0, inplace = True)

# %%
df.head()
# Out:
#    YEAR  MONTH                   SUPPLIER ITEM CODE  \
# 1  2020      1                  PWSWN INC    100024
# 2  2020      1    RELIABLE CHURCHILL LLLP      1001
# 3  2020      1  LANTERNA DISTRIBUTORS INC    100145
# 4  2020      1       DIONYSOS IMPORTS INC    100293
# 5  2020      1    KYSELA PERE ET FILS LTD    100641
#
#                       ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 1            MOMENT DE PLAISIR - 750ML      WINE          0.00
# 2  S SMITH ORGANIC PEAR CIDER - 18.7OZ      BEER          0.00
# 3        SCHLINK HAUS KABINETT - 750ML      WINE          0.00
# 4       SANTORINI GAVALA WHITE - 750ML      WINE          0.82
# 5      CORTENOVA VENETO P/GRIG - 750ML      WINE          2.76
#
#    RETAIL TRANSFERS  WAREHOUSE SALES      NEW_CODE  it-b
# 1               1.0              4.0  100024100024  WINE
# 2               0.0              1.0      10011001  BEER
# 3               0.0              1.0  100145100145  WINE
# ...

# %% [markdown]
# *   axis = 1: column
# *   axis = 0: row

# %%
df.drop(1, axis = 0)
# Out:
#         YEAR  MONTH                   SUPPLIER ITEM CODE  \
# 2       2020      1    RELIABLE CHURCHILL LLLP      1001
# 3       2020      1  LANTERNA DISTRIBUTORS INC    100145
# 4       2020      1       DIONYSOS IMPORTS INC    100293
# 5       2020      1    KYSELA PERE ET FILS LTD    100641
# 6       2020      1   SANTA MARGHERITA USA INC    100749
# ...      ...    ...                        ...       ...
# 307640  2020      9                   DOPS INC     97896
# 307641  2020      9         ANHEUSER BUSCH INC     97918
# 307642  2020      9               HEINEKEN USA     97942
# 307643  2020      9    RELIABLE CHURCHILL LLLP     97950
# 307644  2020      9    RELIABLE CHURCHILL LLLP     97969
#
#                                    ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 2               S SMITH ORGANIC PEAR CIDER - 18.7OZ      BEER          0.00
# 3                     SCHLINK HAUS KABINETT - 750ML      WINE          0.00
# ...

# %%
df.drop(1, axis = 0, inplace = True)
